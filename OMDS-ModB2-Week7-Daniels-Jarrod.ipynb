# %% [markdown]
# # Week 7 - Milestone One week

# %% [markdown]
# # 1. Lesson: no lesson this week.  Milestone One is due!

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# Below are the graphs from last week's weekly graph question.  Suppose you wanted to cause the viewer to examine the last three months of data first.  How could you use preattentive attributes to do that?  Suggest several possibilities.

# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
numdates = 12
np.random.seed(0)
time_series = 100 * (np.random.normal(size = numdates) / 5 + np.arange(numdates) / 16)
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
ax = sns.lineplot(x = datearray, y = time_series)
ax.set_xlabel("Year and month")
ax.set_ylabel("Nitrate level (% of eutrophic value)")
# Out:
# C:\Users\jdblu\AppData\Local\Temp\ipykernel_24648\2149468501.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
# Text(0, 0.5, 'Nitrate level (% of eutrophic value)')

# %%
np.random.seed(1)
time_series = 100 * (1 - (np.random.normal(size = numdates) / 8 + np.arange(numdates) / 16))
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
ax = sns.lineplot(x = datearray, y = time_series)
ax.set_xlabel("Year and month")
ax.set_ylabel("Phosphate level (% of eutrophic value)")
# Out:
# C:\Users\jdblu\AppData\Local\Temp\ipykernel_24648\1012779568.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
# Text(0, 0.5, 'Phosphate level (% of eutrophic value)')

# %% [markdown]
# Looking at our Nitrate and Phosphate graphs from last week, there are a few possibly steps we could take to emphasize just the last three months worth of data. Some potential solutions might involve...
#
# - Make the last three months of the on the graph a bold or saturated color, while alternatively making the months prior to our range more dull and muted colors
# - Make the line width for the desired month range thicker/bolder than that of the rest of the graph
# - Use distinctive markers (such as circles/squares) only for the the three months that we want to highlight
# - Shade the background of the three month range that we want to highlight (refer to chart 3.6 on page 77 of the textbook).
# - Directly call out via labels areas of interest (this could be done via arrows or text)

# %% [markdown]
# # 3. Working on your datasets
#
# This week, you can work on Milestone One rather than having a particular exercise about working on your datasets

# %% [markdown]
# # 4. Storytelling With Data plot
#
# Reproduce any graph of your choice in p. 99-119 of the Storytelling With Data book as best you can. (The first half of chapter four). You do not have to get the exact data values right, just the overall look and feel.

# %%
import matplotlib.pyplot as plt

#data from the book chart
concerns = [
    "Engine power is less than expected",
    "Tires make excessive noise while driving",
    "Engine makes abnormal/excessive noise",
    "Seat material concerns",
    "Excessive wind noise",
    "Hesitation or delay when shifting",
    "Bluetooth system has poor sound quality",
    "Steering system/wheel has too much play",
    "Bluetooth system is difficult to use",
    "Front seat audio/entertainment/navigation controls"
]

values = [12.9, 12.3, 11.6, 11.6, 11.0, 10.3, 10.0, 8.8, 8.6, 8.2]

#set our first ten values to be red, while the last three will be grey
colors = ['firebrick'] * 7 + ['gray'] * 3


fig, ax = plt.subplots(figsize=(6, 5))
bars = ax.barh(concerns, values, color=colors)

#add value labels to the inside of the bard chart
for bar in bars:
    width = bar.get_width()
    ax.text(width - 0.5, bar.get_y() + bar.get_height()/2,
            f'{width:.1f}', ha='right', va='center', color='white', fontsize=10)

#styling
ax.invert_yaxis() #flips bar chart from vertical to horizontal
ax.set_title("Top 10 design concerns", fontsize=14, loc='left', weight='bold')
ax.set_xlabel("concerns per 1,000", fontsize=10)
ax.set_xlim(0, 14)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
ax.set_xticklabels([])
plt.tight_layout()
plt.show()
